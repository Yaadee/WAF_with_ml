# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\hp\desktop\ame\.venv\lib\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading and Exploration

# %%
anomaly_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/anomaliousTraffic.csv")
normal_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/normalTraffic.csv")
web_traffic_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/web_traffic.csv")
# Display the first few rows of each dataset
print("Anomalous Traffic Data:")
print(anomaly_df.head())

print("\nNormal Traffic Data:")
print(normal_df.head())

print("\nWeb Traffic Data:")
print(web_traffic_df.head())

# Get the column names
anomaly_columns = list(anomaly_df.columns)
normal_columns = list(normal_df.columns)
web_traffic_columns = list(web_traffic_df.columns)

print("\nAnomalous Traffic Columns:", anomaly_columns)
print("Normal Traffic Columns:", normal_columns)
print("Web Traffic Columns:", web_traffic_columns)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19920\1036659372.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   anomaly_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/anomaliousTraffic.csv")
# C:\Users\HP\AppData\Local\Temp\ipykernel_19920\1036659372.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   normal_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/normalTraffic.csv")
# Anomalous Traffic Data:
#    index method                                               url  protocol  \
# 0      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 1      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 2      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 4      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
#
#                                            userAgent    pragma cacheControl  \
# 0  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 2  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 3  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 4  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
#
#                                               accept  \
# 0  text/xml,application/xml,application/xhtml+xml...
# 1  text/xml,application/xml,application/xhtml+xml...
# 2  text/xml,application/xml,application/xhtml+xml...
# 3  text/xml,application/xml,application/xhtml+xml...
# 4  text/xml,application/xml,application/xhtml+xml...
#
#                      acceptEncoding                acceptCharset  \
# 0  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#   acceptLanguage            host connection  contentLength contentType  \
# 0             en  localhost:8080      close            NaN         NaN
# 1             en  localhost:8080      close            NaN         NaN
# 2             en  localhost:8080      close            NaN         NaN
# 3             en  localhost:8080      close            NaN         NaN
# 4             en  localhost:8080      close            NaN         NaN
#
#                                         cookie  \
# 0  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 1  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 2  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 3  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 4  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
#
#                                              payload label
# 0                                               id=2  anom
# 1                           nombre=Jam%F3n+Ib%E9rico  anom
# 2                                          precio=85  anom
# 3  cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                             B1=A%F1adir+al+carrito  anom
#
# Normal Traffic Data:
#    index method                                               url  protocol  \
# 0      0    GET           http://localhost:8080/tienda1/index.jsp  HTTP/1.1
# 1      1    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 2      1    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3      1    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 4      1    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
#
#                                            userAgent    pragma cacheControl  \
# 0  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 2  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 3  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 4  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
#
#                                               accept  \
# 0  text/xml,application/xml,application/xhtml+xml...
# 1  text/xml,application/xml,application/xhtml+xml...
# 2  text/xml,application/xml,application/xhtml+xml...
# 3  text/xml,application/xml,application/xhtml+xml...
# 4  text/xml,application/xml,application/xhtml+xml...
#
#                      acceptEncoding                acceptCharset  \
# 0  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#   acceptLanguage            host connection  contentLength contentType  \
# 0             en  localhost:8080      close            NaN         NaN
# 1             en  localhost:8080      close            NaN         NaN
# 2             en  localhost:8080      close            NaN         NaN
# 3             en  localhost:8080      close            NaN         NaN
# 4             en  localhost:8080      close            NaN         NaN
#
#                                         cookie            payload label
# 0  JSESSIONID=1F767F17239C9B670A39E9B10C3825F4                NaN  norm
# 1  JSESSIONID=81761ACA043B0E6014CA42A4BCD06AB5               id=3  norm
# 2  JSESSIONID=81761ACA043B0E6014CA42A4BCD06AB5  nombre=Vino+Rioja  norm
# 3  JSESSIONID=81761ACA043B0E6014CA42A4BCD06AB5         precio=100  norm
# 4  JSESSIONID=81761ACA043B0E6014CA42A4BCD06AB5        cantidad=55  norm
#
# Web Traffic Data:
#    index method                                               url  protocol  \
# 0      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 1      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 2      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 4      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
#
#                                            userAgent    pragma cacheControl  \
# 0  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 2  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 3  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 4  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
#
#                                               accept  \
# 0  text/xml,application/xml,application/xhtml+xml...
# 1  text/xml,application/xml,application/xhtml+xml...
# 2  text/xml,application/xml,application/xhtml+xml...
# 3  text/xml,application/xml,application/xhtml+xml...
# 4  text/xml,application/xml,application/xhtml+xml...
#
#                      acceptEncoding                acceptCharset  \
# 0  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#   acceptLanguage            host connection  contentLength contentType  \
# 0             en  localhost:8080      close            NaN         NaN
# 1             en  localhost:8080      close            NaN         NaN
# 2             en  localhost:8080      close            NaN         NaN
# 3             en  localhost:8080      close            NaN         NaN
# 4             en  localhost:8080      close            NaN         NaN
#
#                                         cookie  \
# 0  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 1  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 2  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 3  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 4  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
#
#                                              payload label
# 0                                               id=2  anom
# 1                           nombre=Jam%F3n+Ib%E9rico  anom
# 2                                          precio=85  anom
# 3  cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                             B1=A%F1adir+al+carrito  anom
#
# Anomalous Traffic Columns: ['index', 'method', 'url', 'protocol', 'userAgent', 'pragma', 'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset', 'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType', 'cookie', 'payload', 'label']
# Normal Traffic Columns: ['index', 'method', 'url', 'protocol', 'userAgent', 'pragma', 'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset', 'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType', 'cookie', 'payload', 'label']
# Web Traffic Columns: ['index', 'method', 'url', 'protocol', 'userAgent', 'pragma', 'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset', 'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType', 'cookie', 'payload', 'label']
# C:\Users\HP\AppData\Local\Temp\ipykernel_19920\1036659372.py:3: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   web_traffic_df = pd.read_csv("C:/Users/HP/Desktop/ame/data/web_traffic.csv")

# %%
print("Anomalous Traffic Columns:", anomaly_df.columns)
print("Normal Traffic Columns:", normal_df.columns)
print("Web Traffic Columns:", web_traffic_df.columns)
# Out:
# Anomalous Traffic Columns: Index(['index', 'method', 'url', 'protocol', 'userAgent', 'pragma',
#        'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset',
#        'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType',
#        'cookie', 'payload', 'label'],
#       dtype='object')
# Normal Traffic Columns: Index(['index', 'method', 'url', 'protocol', 'userAgent', 'pragma',
#        'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset',
#        'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType',
#        'cookie', 'payload', 'label'],
#       dtype='object')
# Web Traffic Columns: Index(['index', 'method', 'url', 'protocol', 'userAgent', 'pragma',
#        'cacheControl', 'accept', 'acceptEncoding', 'acceptCharset',
#        'acceptLanguage', 'host', 'connection', 'contentLength', 'contentType',
#        'cookie', 'payload', 'label'],
#       dtype='object')

# %% [markdown]
# # explanatory Data Analysis

# %%
# Summary statistics
print("\nAnomalous Traffic Summary:")
print(anomaly_df.describe())

print("\nNormal Traffic Summary:")
print(normal_df.describe())

print("\nWeb Traffic Summary:")
print(web_traffic_df.describe())
# Out:
# Anomalous Traffic Summary:
#                index  contentLength
# count  119585.000000    58135.00000
# mean    13631.637613      198.92483
# std      7276.230752      109.27159
# min         0.000000        4.00000
# 25%      7373.000000       74.00000
# 50%     14668.000000      247.00000
# 75%     19944.000000      265.00000
# max     25064.000000      836.00000
#
# Normal Traffic Summary:
#                index  contentLength
# count  104000.000000   42000.000000
# mean    21268.153846     176.550857
# std     10914.638765      98.907328
# min         0.000000       4.000000
# 25%     11741.000000      65.000000
# 50%     23483.000000     242.000000
# 75%     31047.000000     256.000000
# max     35999.000000     307.000000
#
# Web Traffic Summary:
#                index  contentLength
# count  223585.000000  100135.000000
# mean    17183.743918     189.540430
# std      9911.489433     105.627152
# min         0.000000       4.000000
# 25%      8873.000000      70.000000
# 50%     17193.000000     244.000000
# 75%     24117.000000     261.000000
# max     35999.000000     836.000000

# %%
anomaly_df.head()
# Out:
#    index method                                               url  protocol  \
# 0      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 1      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 2      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 3      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
# 4      0    GET  http://localhost:8080/tienda1/publico/anadir.jsp  HTTP/1.1
#
#                                            userAgent    pragma cacheControl  \
# 0  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 1  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 2  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 3  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
# 4  Mozilla/5.0 (compatible; Konqueror/3.5; Linux)...  no-cache     no-cache
#
#                                               accept  \
# 0  text/xml,application/xml,application/xhtml+xml...
# 1  text/xml,application/xml,application/xhtml+xml...
# 2  text/xml,application/xml,application/xhtml+xml...
# 3  text/xml,application/xml,application/xhtml+xml...
# 4  text/xml,application/xml,application/xhtml+xml...
#
#                      acceptEncoding                acceptCharset  \
# 0  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 1  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 2  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 3  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 4  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#   acceptLanguage            host connection  contentLength contentType  \
# 0             en  localhost:8080      close            NaN         NaN
# 1             en  localhost:8080      close            NaN         NaN
# 2             en  localhost:8080      close            NaN         NaN
# 3             en  localhost:8080      close            NaN         NaN
# 4             en  localhost:8080      close            NaN         NaN
#
#                                         cookie  \
# 0  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 1  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 2  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 3  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
# 4  JSESSIONID=B92A8B48B9008CD29F622A994E0F650D
#
#                                              payload label
# 0                                               id=2  anom
# 1                           nombre=Jam%F3n+Ib%E9rico  anom
# 2                                          precio=85  anom
# 3  cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 4                             B1=A%F1adir+al+carrito  anom

# %%
# Check for missing values
print("\nMissing Values in Anomalous Traffic Data:")
print(anomaly_df.isnull().sum())

print("\nMissing Values in Normal Traffic Data:")
print(normal_df.isnull().sum())
# Out:
# Missing Values in Anomalous Traffic Data:
# index                 0
# method                0
# url                   0
# protocol              0
# userAgent             0
# pragma                0
# cacheControl          0
# accept                0
# acceptEncoding        0
# acceptCharset         0
# acceptLanguage        0
# host                  0
# connection            0
# contentLength     61450
# contentType       61450
# cookie                0
# payload            5491
# label                 0
# dtype: int64
#
# Missing Values in Normal Traffic Data:
# index                 0
# method                0
# url                   0
# protocol              0
# userAgent             0
# pragma                0
# cacheControl          0
# accept                0
# acceptEncoding        0
# acceptCharset         0
# acceptLanguage        0
# host                  0
# connection            0
# contentLength     62000
# contentType       62000
# cookie                0
# payload           20000
# label                 0
# dtype: int64

# %%
print("\nMissing Values in Web Traffic Data:")
print(web_traffic_df.isnull().sum())
# Out:
# Missing Values in Web Traffic Data:
# index                  0
# method                 0
# url                    0
# protocol               0
# userAgent              0
# pragma                 0
# cacheControl           0
# accept                 0
# acceptEncoding         0
# acceptCharset          0
# acceptLanguage         0
# host                   0
# connection             0
# contentLength     123450
# contentType       123450
# cookie                 0
# payload            25491
# label                  0
# dtype: int64

# %%
anomaly_df['contentLength'] = pd.to_numeric(anomaly_df['contentLength'], errors='coerce')
normal_df['contentLength'] = pd.to_numeric(normal_df['contentLength'], errors='coerce')
web_traffic_df['contentLength'] = pd.to_numeric(web_traffic_df['contentLength'], errors='coerce')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting contentLength distribution for the Anomalous Traffic
sns.histplot(anomaly_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Anomalous Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

# Plotting contentLength distribution for the Normal Traffic
sns.histplot(normal_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Normal Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

# Plotting contentLength distribution for Web Traffic
sns.histplot(web_traffic_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Web Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot for the 'method' feature
sns.countplot(x='method', data=anomaly_df)
plt.title('HTTP Methods in Anomalous Traffic')
plt.show()
sns.countplot(x='method', data=normal_df)
plt.title('HTTP Methods in Normal Traffic')
plt.show()
sns.countplot(x='method', data=web_traffic_df)
plt.title('HTTP Methods in Web Traffic')
plt.show()

# %%
print(anomaly_df['payload'].dtype)
print(normal_df['payload'].dtype)
# Out:
# object
# object

# %%
print(anomaly_df['payload'].isnull().sum())
print(normal_df['payload'].isnull().sum())
# Out:
# 5491
# 20000

# %%
print(anomaly_df['payload'].describe())
print(normal_df['payload'].describe())
# Out:
# count           114094
# unique           14681
# top       B1=Registrar
# freq              5261
# Name: payload, dtype: object
# count             84000
# unique            19418
# top       modo=registro
# freq               4000
# Name: payload, dtype: object

# %% [markdown]
# # Data preprocessing

# %%
# Impute or drop missing values
anomaly_df = anomaly_df.dropna()
normal_df = normal_df.dropna()
web_traffic_df = web_traffic_df.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# List of categorical columns that need encoding
categorical_cols = ['method', 'url', 'protocol', 'userAgent']

# Encoding categorical variables for each dataset
for col in categorical_cols:
    anomaly_df[col] = le.fit_transform(anomaly_df[col])
    normal_df[col] = le.transform(normal_df[col])
    web_traffic_df[col] = le.transform(web_traffic_df[col])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting the frequency of different HTTP methods (after encoding)
sns.countplot(x='method', data=anomaly_df)
plt.title('Frequency of HTTP Methods in Anomalous Traffic')
plt.show()

sns.countplot(x='method', data=normal_df)
plt.title('Frequency of HTTP Methods in Normal Traffic')
plt.show()

sns.countplot(x='method', data=web_traffic_df)
plt.title('Frequency of HTTP Methods in Web Traffic')
plt.show()

# %%
# Plotting the frequency of User Agents (after encoding)
sns.countplot(x='userAgent', data=anomaly_df)
plt.title('User Agents in Anomalous Traffic')
plt.show()

sns.countplot(x='userAgent', data=normal_df)
plt.title('User Agents in Normal Traffic')
plt.show()

sns.countplot(x='userAgent', data=web_traffic_df)
plt.title('User Agents in Web Traffic')
plt.show()

# %%
# Visualizing the distribution of contentLength
sns.histplot(anomaly_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Anomalous Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

sns.histplot(normal_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Normal Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

sns.histplot(web_traffic_df['contentLength'], kde=True, bins=30)
plt.title('Distribution of Content Length in Web Traffic')
plt.xlabel('Content Length')
plt.ylabel('Frequency')
plt.show()

# %%
# Select only the numeric columns from anomaly_df
numeric_cols = anomaly_df.select_dtypes(include=['float64', 'int64']).columns

# Now create the correlation heatmap using only numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(anomaly_df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Anomalous Traffic')
plt.show()

# Repeat for normal_df
numeric_cols_normal = normal_df.select_dtypes(include=['float64', 'int64']).columns
plt.figure(figsize=(12, 8))
sns.heatmap(normal_df[numeric_cols_normal].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Normal Traffic')
plt.show()

# Repeat for web_traffic_df
numeric_cols_web = web_traffic_df.select_dtypes(include=['float64', 'int64']).columns
plt.figure(figsize=(12, 8))
sns.heatmap(web_traffic_df[numeric_cols_web].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Web Traffic')
plt.show()

# %%
anomaly_df.head()
# Out:
#        index  method  url  protocol  userAgent    pragma cacheControl  \
# 61450  15088       0    1         0          0  no-cache     no-cache
# 61451  15088       0    1         0          0  no-cache     no-cache
# 61452  15088       0    1         0          0  no-cache     no-cache
# 61453  15088       0    1         0          0  no-cache     no-cache
# 61454  15088       0    1         0          0  no-cache     no-cache
#
#                                                   accept  \
# 61450  text/xml,application/xml,application/xhtml+xml...
# 61451  text/xml,application/xml,application/xhtml+xml...
# 61452  text/xml,application/xml,application/xhtml+xml...
# 61453  text/xml,application/xml,application/xhtml+xml...
# 61454  text/xml,application/xml,application/xhtml+xml...
#
#                          acceptEncoding                acceptCharset  \
# 61450  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 61451  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 61452  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 61453  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
# 61454  x-gzip, x-deflate, gzip, deflate  utf-8, utf-8;q=0.5, *;q=0.5
#
#       acceptLanguage            host connection  contentLength  \
# 61450             en  localhost:8080      close          146.0
# 61451             en  localhost:8080      close          146.0
# 61452             en  localhost:8080      close          146.0
# 61453             en  localhost:8080      close          146.0
# 61454             en  localhost:8080      close          146.0
#
#                              contentType  \
# 61450  application/x-www-form-urlencoded
# 61451  application/x-www-form-urlencoded
# 61452  application/x-www-form-urlencoded
# 61453  application/x-www-form-urlencoded
# 61454  application/x-www-form-urlencoded
#
#                                             cookie  \
# 61450  JSESSIONID=AE29AEEBDE479D5E1A18B4108C8E3CE0
# 61451  JSESSIONID=AE29AEEBDE479D5E1A18B4108C8E3CE0
# 61452  JSESSIONID=AE29AEEBDE479D5E1A18B4108C8E3CE0
# 61453  JSESSIONID=AE29AEEBDE479D5E1A18B4108C8E3CE0
# 61454  JSESSIONID=AE29AEEBDE479D5E1A18B4108C8E3CE0
#
#                                                  payload label
# 61450                                               id=2  anom
# 61451                           nombre=Jam%F3n+Ib%E9rico  anom
# 61452                                          precio=85  anom
# 61453  cantidad=%27%3B+DROP+TABLE+usuarios%3B+SELECT+...  anom
# 61454                             B1=A%F1adir+al+carrito  anom

# %% [markdown]
# # feature Scaling

# %%
# Identify numerical columns (excluding non-numeric columns like 'pragma', 'cacheControl', etc.)
numerical_cols = ['contentLength']  # Add any other purely numerical columns if available

# Check for other possible numerical columns and update the list accordingly
print(anomaly_df[numerical_cols].head())
print(normal_df[numeric_cols].head())
print(web_traffic_df[numeric_cols].head())
# Out:
#        contentLength
# 61450          146.0
# 61451          146.0
# 61452          146.0
# 61453          146.0
# 61454          146.0
#        index  method  url  protocol  userAgent  contentLength
# 62000  28000       0    1         0          0           68.0
# 62001  28000       0    1         0          0           68.0
# 62002  28000       0    1         0          0           68.0
# 62003  28000       0    1         0          0           68.0
# 62004  28000       0    1         0          0           68.0
#        index  method  url  protocol  userAgent  contentLength
# 61450  15088       0    1         0          0          146.0
# 61451  15088       0    1         0          0          146.0
# 61452  15088       0    1         0          0          146.0
# 61453  15088       0    1         0          0          146.0
# 61454  15088       0    1         0          0          146.0

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Scale the numerical columns in each dataset
anomaly_df[numerical_cols] = scaler.fit_transform(anomaly_df[numerical_cols])
normal_df[numerical_cols] = scaler.transform(normal_df[numerical_cols])
web_traffic_df[numerical_cols] = scaler.transform(web_traffic_df[numerical_cols])

# Check the scaled results
print(anomaly_df[numerical_cols].head())
print(normal_df[numerical_cols].head())
print(web_traffic_df[numerical_cols].head())
# Out:
#        contentLength
# 61450      -0.484346
# 61451      -0.484346
# 61452      -0.484346
# 61453      -0.484346
# 61454      -0.484346
#        contentLength
# 62000       -1.19817
# 62001       -1.19817
# 62002       -1.19817
# 62003       -1.19817
# 62004       -1.19817
#        contentLength
# 61450      -0.484346
# 61451      -0.484346
# 61452      -0.484346
# 61453      -0.484346
# 61454      -0.484346

# %% [markdown]
# #  Preparing Data for CNN

# %%
import numpy as np

# Combine datasets and create labels
anomaly_df['label'] = 1  # Anomalous traffic
normal_df['label'] = 0   # Normal traffic

data = pd.concat([anomaly_df, normal_df], ignore_index=True)

# Separate features and labels
X = data.drop('label', axis=1)
y = data['label']

# Reshape data for CNN
X_cnn = X.values.reshape(-1, X.shape[1], 1)

# %% [markdown]
# # Building the CNN Model

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   
#    ------ -------------------------------- 68.4/385.2 MB 419.7 kB/s eta 0:12:35
#    ------ -------------------------------- 68.7/385.2 MB 426.5 kB/s eta 0:12:22
#    ------ -------------------------------- 68.7/385.2 MB 426.5 kB/s eta 0:12:22
#    ------ -------------------------------- 68.9/385.2 MB 429.1 kB/s eta 0:12:17
#    ------ -------------------------------- 68.9/385.2 MB 429.1 kB/s eta 0:12:17
#    ------- ------------------------------- 69.2/385.2 MB 439.9 kB/s eta 0:11:59
#    ------- ------------------------------- 69.2/385.2 MB 439.9 kB/s eta 0:11:59
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
#    ------- ------------------------------- 69.5/385.2 MB 442.7 kB/s eta 0:11:54
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Exception:
# Traceback (most recent call last):
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\http\client.py", line 479, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\ssl.py", line 1251, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\ssl.py", line 1103, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\cli\base_command.py", line 105, in _run_wrapper
#     status = _inner_run()
#              ^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\cli\base_command.py", line 96, in _inner_run
#     return self.run(options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\cli\req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\commands\install.py", line 379, in run
#     requirement_set = resolver.resolve(
#                       ^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 179, in resolve
#     self.factory.preparer.prepare_linked_requirements_more(reqs)
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\operations\prepare.py", line 554, in prepare_linked_requirements_more
#     self._complete_partial_requirements(
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\operations\prepare.py", line 469, in _complete_partial_requirements
#     for link, (filepath, _) in batch_download:
#                                ^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\network\download.py", line 184, in __call__
#     for chunk in chunks:
#                  ^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\cli\progress_bars.py", line 55, in _rich_progress_bar
#     for chunk in iterable:
#                  ^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_internal\network\utils.py", line 65, in response_chunks
#     for chunk in response.raw.stream(
#                  ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 622, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 560, in read
#     with self._error_catcher():
#          ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "c:\Users\HP\Desktop\ame\.venv\Lib\site-packages\pip\_vendor\urllib3\response.py", line 443, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.

# %%
pip install keras
# Out:
# Collecting keras
#   Using cached keras-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting absl-py (from keras)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in c:\users\hp\desktop\ame\.venv\lib\site-packages (from keras) (2.1.1)
# Collecting rich (from keras)
#   Using cached rich-13.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting h5py (from keras)
#   Using cached h5py-3.12.1-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# Collecting optree (from keras)
#   Using cached optree-0.12.1-cp312-cp312-win_amd64.whl.metadata (48 kB)
# Collecting ml-dtypes (from keras)
#   Downloading ml_dtypes-0.5.0-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: packaging in c:\users\hp\desktop\ame\.venv\lib\site-packages (from keras) (24.1)
# Collecting typing-extensions>=4.5.0 (from optree->keras)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\desktop\ame\.venv\lib\site-packages (from rich->keras) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading keras-3.5.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    ------------------ --------------------- 0.5/1.1 MB 102.3 kB/s eta 0:00:07
#    --------------------- ------------------ 1.6/3.0 MB 220.8 kB/s eta 0:00:07
#    --------------------- ------------------ 1.6/3.0 MB 220.8 kB/s eta 0:00:07
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 222.2 kB/s eta 0:00:06
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ---------------------------- ----------- 2.1/3.0 MB 219.9 kB/s eta 0:00:05
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ------------------------------- -------- 2.4/3.0 MB 194.2 kB/s eta 0:00:04
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    ----------------------------------- ---- 2.6/3.0 MB 183.9 kB/s eta 0:00:03
#    -------------------------------------- - 2.9/3.0 MB 176.6 kB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 176.6 kB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 176.6 kB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 176.6 kB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 175.8 kB/s eta 0:00:00
# Downloading ml_dtypes-0.5.0-cp312-cp312-win_amd64.whl (213 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.12.1-cp312-cp312-win_amd64.whl (267 kB)
# Downloading rich-13.8.1-py3-none-any.whl (241 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, typing-extensions, ml-dtypes, mdurl, h5py, absl-py, optree, markdown-it-py, rich, keras
# Successfully installed absl-py-2.1.0 h5py-3.12.1 keras-3.5.0 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.5.0 namex-0.0.8 optree-0.12.1 rich-13.8.1 typing-extensions-4.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# Define the CNN model
cnn_model = Sequential()
cnn_model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X.shape[1], 1)))
cnn_model.add(MaxPooling1D(pool_size=2))
cnn_model.add(Flatten())
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dense(1, activation='sigmoid'))

cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Extract features
features = cnn_model.predict(X_cnn)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
#       4 # Define the CNN model
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip show tensorflow
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: tensorflow
